# %%
import re
import pandas as pd
import googlemaps as gm
from googlemaps import client
client = gm.Client("AIzaSyCHAHf6pYK6wvCRmM12v0tZPKuGnXygrOs")
from googlemaps import geocoding
geocode = geocoding.geocode

# %%
import os
os.getcwd()
# Out:
# '/Users/maggiezhang/Desktop/Projects/BIDS/week1'

# %%
raw_data = pd.read_csv("Burlington_Logs copy.csv")

# %%
locationdata = raw_data['Location']
locationdata
# Out:
# 0                              North St
# 1                               Pine St
# 2                               Bank St
# 3                        Colchester Ave
# 4                              North St
# 5                              Pearl St
# 6       Elmwood Ave Burlington VT 05401
# 7                        N Winooski Ave
# 8                Central Ave/Wright Ave
# 9                              North St
# 10                            North Ave
# 11                    Bank St/Church St
# 12                           St Paul St
# 13                   St Paul St/King St
# 14                              Pine St
# 15                 Elmwood Ave/North St
# 16                   Beltline/North Ave
# 17                             Pearl St
# 18                        S Prospect St
# 19                            Church St
# 20                    Pine St/Flynn Ave
# 21                              Pine St
# 22                        Riverside Ave
# ...

# %%
longitude = []
latitude = []
for i in locationdata:
    if '/' in i:
        i= i.replace('/', '&')
    address = i
    data = geocode(client, address+" , Burlington")[0]['geometry']['location']
    lat = data['lat']
    lng = data['lng']
    longitude.append(lat)
    latitude.append(lng)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-66a5e9c0e9ed> in <module>()
#       2 latitude = []
#       3 for i in locationdata:
# ----> 4     if '/' in i:
#       5         i= i.replace('/', '&')
#       6     address = i
#
# TypeError: argument of type 'float' is not iterable

# %%
raw_data['Long']= longitude
raw_data['Lat'] = latitude
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a9dc21912c63> in <module>()
# ----> 1 raw_data['Long']= longitude
#       2 raw_data['Lat'] = latitude
#
# /Users/maggiezhang/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2297         else:
#    2298             # set column
# -> 2299             self._set_item(key, value)
#    2300
#    2301     def _setitem_slice(self, key, value):
#
# /Users/maggiezhang/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2364
#    2365         self._ensure_valid_index(value)
# -> 2366         value = self._sanitize_column(key, value)
#    2367         NDFrame._set_item(self, key, value)
#    2368
#
# /Users/maggiezhang/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value)
#    2522
# ...

# %%
raw_data
# Out:
#       Incident Id            Call Type                    Date  \
# 0          207424  Mental Health Issue  12/31/2013 12:38:00 PM
# 1          207193  Mental Health Issue  12/30/2013 08:28:00 PM
# 2          206810  Mental Health Issue  12/29/2013 10:57:00 PM
# 3          206685  Mental Health Issue  12/29/2013 04:23:00 PM
# 4          206628  Mental Health Issue  12/29/2013 01:50:00 PM
# 5          205782  Mental Health Issue  12/27/2013 04:03:00 PM
# 6          205640  Mental Health Issue  12/27/2013 10:19:00 AM
# 7          205572  Mental Health Issue  12/27/2013 07:24:00 AM
# 8          204972  Mental Health Issue  12/25/2013 03:12:00 PM
# 9          204940  Mental Health Issue  12/25/2013 01:41:00 PM
# 10         204522  Mental Health Issue  12/24/2013 07:47:00 AM
# 11         204330  Mental Health Issue  12/23/2013 07:01:00 PM
# 12         204085  Mental Health Issue  12/23/2013 10:29:00 AM
# 13         203730  Mental Health Issue  12/22/2013 11:09:00 AM
# ...

# %%
raw_data.to_csv("Burlington.csv")
