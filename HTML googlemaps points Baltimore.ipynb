# %%
import pandas as pd

# %%
raw_data = pd.read_csv("BaltimoreLogs.csv")
data = raw_data[0:2205]
i = 0;
while i < len(data.location):
    print('new google.maps.LatLng '+ str(data['location'].loc[i]) +",")
    i = i + 1
# Out:
# new google.maps.LatLng (39.3140964,-76.7030143),
# new google.maps.LatLng (39.2864167,-76.5722495),
# new google.maps.LatLng (39.3140964,-76.7030143),
# new google.maps.LatLng (39.311114,-76.617911),
# new google.maps.LatLng (39.3140964,-76.7030143),
# new google.maps.LatLng (39.3585046,-76.5781415),
# new google.maps.LatLng (39.240219,-76.606996),
# new google.maps.LatLng (39.2872343,-76.5503639),
# new google.maps.LatLng (39.3261100,-76.6164000),
# new google.maps.LatLng (39.2981690,-76.6901550),
# new google.maps.LatLng (39.2786293,-76.6589751),
# new google.maps.LatLng (39.2961328,-76.6255206),
# new google.maps.LatLng (39.3221790,-76.5402740),
# new google.maps.LatLng (39.2320080,-76.5962640),
# new google.maps.LatLng (39.3326670,-76.5579990),
# new google.maps.LatLng (39.3371809,-76.5565927),
# new google.maps.LatLng (39.3371809,-76.5565927),
# new google.maps.LatLng (39.3134000,-76.6154330),
# new google.maps.LatLng (39.2962616,-76.6099423),
# ...

# %%
import csv

# %%
len(data.location)
# Out:
# 321
